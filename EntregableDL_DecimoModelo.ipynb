# %% [markdown]
# ![Nuclio logo](https://nuclio.school/wp-content/uploads/2018/12/nucleoDS-newBlack.png)

# %% [markdown]
# ## 1. Librerias & Google Drive
#
# Para empezar carguemos esas librerias que nos hacen falta

# %%
from tensorflow import keras as ks
from matplotlib import pyplot as plt
import numpy as np
import time
import datetime
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import regularizers

from tensorflow.keras.optimizers import SGD

# %% [markdown]
# ## 2. Arquitectura de red del modelo - Proyecto 0

# %%
import tensorflow.keras as ks

model = ks.Sequential()

model.add(ks.layers.Conv2D(128, (3, 3), activation='swish',
                           padding='same',input_shape=(32,32,3)))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Conv2D(128, (3, 3), activation='swish', padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.MaxPooling2D(pool_size=(2, 2)))
model.add(ks.layers.Dropout(0.3))

model.add(ks.layers.Conv2D(256, (3, 3), activation='relu', padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Conv2D(256, (3, 3), activation='relu', padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.MaxPooling2D(pool_size=(2, 2)))
model.add(ks.layers.Dropout(0.4))

model.add(ks.layers.Conv2D(512, (3, 3), activation='swish', padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Conv2D(512, (3, 3), activation='swish', padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.MaxPooling2D(pool_size=(2, 2)))
model.add(ks.layers.Dropout(0.5))

model.add(ks.layers.Conv2D(1024, (3, 3), activation='relu', padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Conv2D(1024, (3, 3), activation='relu', padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Dropout(0.5))

model.add(ks.layers.Flatten())
model.add(ks.layers.Dense(1024, activation='swish'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Dropout(0.4))

model.add(ks.layers.Dense(1024, activation='relu'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Dropout(0.4))

model.add(ks.layers.Dense(10, activation='softmax'))

# %% [markdown]
# Para revisar un modelo, nos basta con llamar al método **.summary()** del modelo

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_8 (Conv2D)                    │ (None, 32, 32, 128)         │           3,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_10               │ (None, 32, 32, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_9 (Conv2D)                    │ (None, 32, 32, 128)         │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_11               │ (None, 32, 32, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 16, 16, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_6 (Dropout)                  │ (None, 16, 16, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_10 (Conv2D)                   │ (None, 16, 16, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_12               │ (None, 16, 16, 256)         │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_11 (Conv2D)                   │ (None, 16, 16, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_13               │ (None, 16, 16, 256)         │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 8, 8, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_7 (Dropout)                  │ (None, 8, 8, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_12 (Conv2D)                   │ (None, 8, 8, 512)           │       1,180,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_14               │ (None, 8, 8, 512)           │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_13 (Conv2D)                   │ (None, 8, 8, 512)           │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_15               │ (None, 8, 8, 512)           │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_5 (MaxPooling2D)       │ (None, 4, 4, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_8 (Dropout)                  │ (None, 4, 4, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_14 (Conv2D)                   │ (None, 4, 4, 1024)          │       4,719,616 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_16               │ (None, 4, 4, 1024)          │           4,096 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_15 (Conv2D)                   │ (None, 4, 4, 1024)          │       9,438,208 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_17               │ (None, 4, 4, 1024)          │           4,096 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_9 (Dropout)                  │ (None, 4, 4, 1024)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 16384)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 1024)                │      16,778,240 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_18               │ (None, 1024)                │           4,096 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_10 (Dropout)                 │ (None, 1024)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 1024)                │       1,049,600 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_19               │ (None, 1024)                │           4,096 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_11 (Dropout)                 │ (None, 1024)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 10)                  │          10,250 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 36,595,850 (139.60 MB)
#  Trainable params: 36,584,074 (139.56 MB)
#  Non-trainable params: 11,776 (46.00 KB)

# %% [markdown]
# ## 3. Optimizador, función error

# %%
model.compile(optimizer='Adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## 4. Preparamos los datos
#
# Cargamos los datos de CIFAR10 de los datasets directamente de las librerias de Keras. Estos ya estan dispuestos en train and test
#
# **Detalle importante:**
# > La red neuronal requiere que los inputs sean números reales, y lo haremos forzando la division de los valores de dentro de las matrices 28x28 (que tienen valoress del 0 al 255) por 255.0 (un real)

# %%
cifar10 = ks.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train_scaled, x_test_scaled = x_train / 255.0, x_test / 255.0

# %%
print("Etiquetas de train:", y_train)


# Convertir los datos en arrays de una dimension (vectores) es una buena mejora en el dataset
y_train = y_train.ravel()
y_test = y_test.ravel()


print("Etiquetas de train (en vector):", y_train)
# Out:
# Etiquetas de train: [[6]
#  [9]
#  [9]
#  ...
#  [9]
#  [1]
#  [1]]
# Etiquetas de train (en vector): [6 9 9 ... 9 1 1]

# %% [markdown]
# Obtenemos un array con todas las labels de CIFAR10

# %%
cifar10_labels = [
'airplane', # id 0
'automobile',
'bird',
'cat',
'deer',
'dog',
'frog',
'horse',
'ship',
'truck'
]

print('Number of labels: %s' % len(cifar10_labels))
# Out:
# Number of labels: 10

# %% [markdown]
# Pintemos una muestra de las imagenes del dataset CIFAR10, a ver si se parece en algo a lo que esperamos.
# Primero, vemos que tipos de datos tengo, después mapeamos esas matrices en una escala de grises utilizando el método **.get_cmap()** de PlotLy con los nueve primeros números del dataset.

# %%
# Pintemos una muestra de las las imagenes del dataset MNIST

print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

for i in range(9):

    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    plt.title(cifar10_labels[y_train[i]])

plt.subplots_adjust(hspace = 1)
plt.show()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000,)
# Test: X=(10000, 32, 32, 3), y=(10000,)

# %% [markdown]
# Como vamos a querer ir haciendo validación a la vez que entrenamos (muy practico)

# %%
x_val_scaled = x_train_scaled[-10000:]
y_val = y_train[-10000:]

x_train_scaled = x_train_scaled[:-10000]
y_train = y_train[:-10000]

# %% [markdown]
# Cuando añadimos convoluciones, necesitamos "pre-tratar los datos", porque **la convolución espera una matriz de 4 campos** (más parecido a "imagenes"), en el caso de MNIST. CIFAR10 ya tiene el shape adecuado, así que no tenemos que hacer nada, pero como siempre decimos: es mejor que comprobeis su tamaño.
#
# Por eso, al salir de la Convolution, hay que hacer un Flatten, porque las capas FullDense esperan arrays, no matrices!!
#
# Luego lo imprimimos para ver que todo está correcto

# %%
# Validamos el resultado
print('Train: X=%s, y=%s' % (x_train_scaled.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test_scaled.shape, y_test.shape))
print('Validation: X=%s, y=%s' % (x_val_scaled.shape, y_val.shape))
# Out:
# Train: X=(40000, 32, 32, 3), y=(40000,)
# Test: X=(10000, 32, 32, 3), y=(10000,)
# Validation: X=(10000, 32, 32, 3), y=(10000,)

# %% [markdown]
# ## 5. Entrenamiento
#
# Ya podemos ponernos a entrenar el modelo!! Ojo, que hemos de entrenar contra los datos convertidos al formato que espera la Convolution.
#
# Empezaremos con 30 epocs, es decir, 30 pasadas completas del dataset (que a su vez sera con mini-batches internamente), fijando un batch de 64
#
# El metodo .fit() nos permite, definir además si disponemos de varias CPUs, GPUs, y si queremos ir validando datos a cada fin de epoch.

# %%
data_generator = ks.preprocessing.image.ImageDataGenerator(
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    rotation_range=20,
    shear_range=0.15,
    zoom_range=0.2,
    fill_mode='nearest'
)

x_train_scaled_gen = data_generator.flow(x_train_scaled, y_train)

# %%
len(x_train_scaled)
# Out:
# 40000

# %%
x_train_scaled_gen.n
# Out:
# 40000

# %%
original_image = x_train_scaled[0]
example_generator = data_generator.flow(np.expand_dims(original_image, axis=0), np.array([0]))
for i in range(35):  # Queremos 15 imágenes, puedes ajustar el número
    plt.subplot(5, 7, i+1)  # 5 filas x 3 columnas
    for X, Y in example_generator:
        image = X[0]  # Tomar la primera imagen del batch
        plt.imshow(image)  # Mostrar la imagen
        plt.axis('off')  # Desactivar los ejes para no ver los números
        break  # Salir del bucle después de obtener una imagen

# Ajustar el diseño y mostrar
plt.tight_layout()
plt.show()

# %%
callback_val_loss = EarlyStopping(monitor="val_loss", patience=15)
callback_val_accuracy = EarlyStopping(monitor="val_accuracy", patience=15)

# %%
t = time.perf_counter()

# %%
history = model.fit(x_train_scaled_gen, epochs=200,
                batch_size= 64, validation_data=(x_val_scaled, y_val),
                callbacks=[callback_val_loss, callback_val_accuracy])
# Out:
# Epoch 1/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 94s 61ms/step - accuracy: 0.2320 - loss: 2.4733 - val_accuracy: 0.3359 - val_loss: 2.2898
# Epoch 2/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 69s 55ms/step - accuracy: 0.3956 - loss: 1.7461 - val_accuracy: 0.5157 - val_loss: 1.5062
# Epoch 3/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 68s 55ms/step - accuracy: 0.4881 - loss: 1.4677 - val_accuracy: 0.4898 - val_loss: 1.7499
# Epoch 4/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 68s 55ms/step - accuracy: 0.5604 - loss: 1.2796 - val_accuracy: 0.4251 - val_loss: 2.2307
# Epoch 5/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 68s 54ms/step - accuracy: 0.6054 - loss: 1.1606 - val_accuracy: 0.7139 - val_loss: 0.8469
# Epoch 6/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 68s 54ms/step - accuracy: 0.6548 - loss: 1.0234 - val_accuracy: 0.7333 - val_loss: 0.8100
# Epoch 7/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 68s 54ms/step - accuracy: 0.6837 - loss: 0.9379 - val_accuracy: 0.7284 - val_loss: 0.8245
# Epoch 8/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 82s 55ms/step - accuracy: 0.7083 - loss: 0.8721 - val_accuracy: 0.7892 - val_loss: 0.6311
# Epoch 9/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 69s 55ms/step - accuracy: 0.7300 - loss: 0.7962 - val_accuracy: 0.7675 - val_loss: 0.7317
# Epoch 10/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 68s 54ms/step - accuracy: 0.7420 - loss: 0.7597 - val_accuracy: 0.7933 - val_loss: 0.6282
# Epoch 11/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 68s 54ms/step - accuracy: 0.7611 - loss: 0.7143 - val_accuracy: 0.7688 - val_loss: 0.7089
# Epoch 12/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 68s 54ms/step - accuracy: 0.7706 - loss: 0.6821 - val_accuracy: 0.7153 - val_loss: 0.8880
# Epoch 13/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 68s 55ms/step - accuracy: 0.7779 - loss: 0.6722 - val_accuracy: 0.8373 - val_loss: 0.4985
# Epoch 14/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 67s 54ms/step - accuracy: 0.7945 - loss: 0.6154 - val_accuracy: 0.8125 - val_loss: 0.5545
# Epoch 15/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 67s 54ms/step - accuracy: 0.7974 - loss: 0.6060 - val_accuracy: 0.8173 - val_loss: 0.5394
# Epoch 16/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 67s 54ms/step - accuracy: 0.8027 - loss: 0.5794 - val_accuracy: 0.8223 - val_loss: 0.5226
# Epoch 17/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 66s 53ms/step - accuracy: 0.8051 - loss: 0.5733 - val_accuracy: 0.8463 - val_loss: 0.4632
# Epoch 18/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 66s 53ms/step - accuracy: 0.8170 - loss: 0.5440 - val_accuracy: 0.8476 - val_loss: 0.4681
# Epoch 19/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 66s 53ms/step - accuracy: 0.8225 - loss: 0.5297 - val_accuracy: 0.8469 - val_loss: 0.5005
# Epoch 20/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 66s 53ms/step - accuracy: 0.8304 - loss: 0.5046 - val_accuracy: 0.8703 - val_loss: 0.5787
# Epoch 21/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 66s 53ms/step - accuracy: 0.8312 - loss: 0.4931 - val_accuracy: 0.8432 - val_loss: 0.5342
# Epoch 22/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 86s 56ms/step - accuracy: 0.8372 - loss: 0.4761 - val_accuracy: 0.8274 - val_loss: 0.5928
# Epoch 23/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 67s 54ms/step - accuracy: 0.8443 - loss: 0.4556 - val_accuracy: 0.8313 - val_loss: 0.5228
# Epoch 24/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 66s 53ms/step - accuracy: 0.8502 - loss: 0.4381 - val_accuracy: 0.8515 - val_loss: 0.5457
# Epoch 25/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 66s 53ms/step - accuracy: 0.8457 - loss: 0.4504 - val_accuracy: 0.8630 - val_loss: 0.4188
# Epoch 26/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 67s 54ms/step - accuracy: 0.8566 - loss: 0.4233 - val_accuracy: 0.8541 - val_loss: 0.4689
# Epoch 27/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 83s 54ms/step - accuracy: 0.8530 - loss: 0.4353 - val_accuracy: 0.8824 - val_loss: 0.6186
# Epoch 28/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 66s 53ms/step - accuracy: 0.8462 - loss: 0.4554 - val_accuracy: 0.8836 - val_loss: 0.3641
# Epoch 29/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 66s 53ms/step - accuracy: 0.8667 - loss: 0.3995 - val_accuracy: 0.8767 - val_loss: 0.3769
# Epoch 30/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 68s 54ms/step - accuracy: 0.8681 - loss: 0.3890 - val_accuracy: 0.8593 - val_loss: 0.4269
# Epoch 31/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 66s 53ms/step - accuracy: 0.8623 - loss: 0.4065 - val_accuracy: 0.8811 - val_loss: 0.3605
# Epoch 32/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 66s 53ms/step - accuracy: 0.8721 - loss: 0.3766 - val_accuracy: 0.8815 - val_loss: 0.3585
# Epoch 33/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 67s 54ms/step - accuracy: 0.8716 - loss: 0.3800 - val_accuracy: 0.8578 - val_loss: 0.4392
# Epoch 34/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 67s 54ms/step - accuracy: 0.8758 - loss: 0.3711 - val_accuracy: 0.8892 - val_loss: 0.3333
# Epoch 35/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 67s 54ms/step - accuracy: 0.8792 - loss: 0.3587 - val_accuracy: 0.8842 - val_loss: 0.3544
# Epoch 36/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 66s 53ms/step - accuracy: 0.8790 - loss: 0.3532 - val_accuracy: 0.8806 - val_loss: 0.3728
# Epoch 37/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 67s 54ms/step - accuracy: 0.8817 - loss: 0.3457 - val_accuracy: 0.8760 - val_loss: 0.3830
# Epoch 38/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 66s 53ms/step - accuracy: 0.8824 - loss: 0.3503 - val_accuracy: 0.8911 - val_loss: 0.3365
# Epoch 39/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 67s 54ms/step - accuracy: 0.8852 - loss: 0.3346 - val_accuracy: 0.8859 - val_loss: 0.3549
# Epoch 40/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 83s 54ms/step - accuracy: 0.8922 - loss: 0.3204 - val_accuracy: 0.8912 - val_loss: 0.3340
# Epoch 41/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 66s 53ms/step - accuracy: 0.8943 - loss: 0.3149 - val_accuracy: 0.8906 - val_loss: 0.3317
# Epoch 42/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 67s 54ms/step - accuracy: 0.8915 - loss: 0.3183 - val_accuracy: 0.8924 - val_loss: 0.3388
# Epoch 43/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 67s 54ms/step - accuracy: 0.8927 - loss: 0.3147 - val_accuracy: 0.8997 - val_loss: 0.3167
# Epoch 44/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 66s 53ms/step - accuracy: 0.8915 - loss: 0.3111 - val_accuracy: 0.8907 - val_loss: 0.3606
# Epoch 45/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 66s 53ms/step - accuracy: 0.8987 - loss: 0.2999 - val_accuracy: 0.9000 - val_loss: 0.3113
# Epoch 46/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 67s 54ms/step - accuracy: 0.8969 - loss: 0.2985 - val_accuracy: 0.9042 - val_loss: 0.3059
# Epoch 47/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 67s 54ms/step - accuracy: 0.9009 - loss: 0.2884 - val_accuracy: 0.8878 - val_loss: 0.3437
# Epoch 48/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 66s 53ms/step - accuracy: 0.8979 - loss: 0.3001 - val_accuracy: 0.8896 - val_loss: 0.3352
# Epoch 49/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 67s 54ms/step - accuracy: 0.8988 - loss: 0.2924 - val_accuracy: 0.9092 - val_loss: 0.2796
# Epoch 50/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 67s 54ms/step - accuracy: 0.9016 - loss: 0.2885 - val_accuracy: 0.8886 - val_loss: 0.3447
# Epoch 51/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 67s 54ms/step - accuracy: 0.9033 - loss: 0.2811 - val_accuracy: 0.9023 - val_loss: 0.3064
# Epoch 52/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 67s 54ms/step - accuracy: 0.9052 - loss: 0.2800 - val_accuracy: 0.8934 - val_loss: 0.3359
# Epoch 53/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 67s 54ms/step - accuracy: 0.9049 - loss: 0.2745 - val_accuracy: 0.9000 - val_loss: 0.3154
# Epoch 54/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 82s 54ms/step - accuracy: 0.9112 - loss: 0.2596 - val_accuracy: 0.9024 - val_loss: 0.3004
# Epoch 55/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 67s 54ms/step - accuracy: 0.9079 - loss: 0.2697 - val_accuracy: 0.8950 - val_loss: 0.3234
# Epoch 56/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 68s 54ms/step - accuracy: 0.9107 - loss: 0.2592 - val_accuracy: 0.9028 - val_loss: 0.3023
# Epoch 57/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 66s 53ms/step - accuracy: 0.9121 - loss: 0.2556 - val_accuracy: 0.8760 - val_loss: 0.3923
# Epoch 58/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 68s 54ms/step - accuracy: 0.9128 - loss: 0.2558 - val_accuracy: 0.8956 - val_loss: 0.3516
# Epoch 59/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 68s 54ms/step - accuracy: 0.9097 - loss: 0.2608 - val_accuracy: 0.8955 - val_loss: 0.3351
# Epoch 60/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 68s 54ms/step - accuracy: 0.9142 - loss: 0.2510 - val_accuracy: 0.9002 - val_loss: 0.3267
# Epoch 61/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 68s 54ms/step - accuracy: 0.9138 - loss: 0.2480 - val_accuracy: 0.9160 - val_loss: 0.2582
# Epoch 62/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 82s 54ms/step - accuracy: 0.9141 - loss: 0.2545 - val_accuracy: 0.9041 - val_loss: 0.3090
# Epoch 63/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 68s 54ms/step - accuracy: 0.9152 - loss: 0.2422 - val_accuracy: 0.9126 - val_loss: 0.2727
# Epoch 64/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 68s 54ms/step - accuracy: 0.9164 - loss: 0.2406 - val_accuracy: 0.9055 - val_loss: 0.3047
# Epoch 65/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 67s 53ms/step - accuracy: 0.9192 - loss: 0.2346 - val_accuracy: 0.9135 - val_loss: 0.2742
# Epoch 66/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 66s 53ms/step - accuracy: 0.9185 - loss: 0.2350 - val_accuracy: 0.9010 - val_loss: 0.3230
# Epoch 67/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 84s 55ms/step - accuracy: 0.9197 - loss: 0.2358 - val_accuracy: 0.9188 - val_loss: 0.2546
# Epoch 68/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 66s 53ms/step - accuracy: 0.9235 - loss: 0.2212 - val_accuracy: 0.9146 - val_loss: 0.2760
# Epoch 69/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 66s 53ms/step - accuracy: 0.9229 - loss: 0.2246 - val_accuracy: 0.9014 - val_loss: 0.3045
# Epoch 70/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 66s 53ms/step - accuracy: 0.9226 - loss: 0.2244 - val_accuracy: 0.8964 - val_loss: 0.3430
# Epoch 71/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 82s 54ms/step - accuracy: 0.9238 - loss: 0.2259 - val_accuracy: 0.9059 - val_loss: 0.3016
# Epoch 72/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 66s 53ms/step - accuracy: 0.9238 - loss: 0.2217 - val_accuracy: 0.9162 - val_loss: 0.2700
# Epoch 73/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 67s 54ms/step - accuracy: 0.9267 - loss: 0.2146 - val_accuracy: 0.9113 - val_loss: 0.2968
# Epoch 74/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 68s 54ms/step - accuracy: 0.9273 - loss: 0.2169 - val_accuracy: 0.9146 - val_loss: 0.2856
# Epoch 75/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 66s 53ms/step - accuracy: 0.9305 - loss: 0.2041 - val_accuracy: 0.9110 - val_loss: 0.2810
# Epoch 76/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 67s 54ms/step - accuracy: 0.9256 - loss: 0.2134 - val_accuracy: 0.8815 - val_loss: 0.4008
# Epoch 77/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 67s 54ms/step - accuracy: 0.9244 - loss: 0.2183 - val_accuracy: 0.9108 - val_loss: 0.2919
# Epoch 78/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 66s 53ms/step - accuracy: 0.9298 - loss: 0.2002 - val_accuracy: 0.9024 - val_loss: 0.3317
# Epoch 79/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 67s 54ms/step - accuracy: 0.9302 - loss: 0.2035 - val_accuracy: 0.9046 - val_loss: 0.3168
# Epoch 80/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 67s 54ms/step - accuracy: 0.9294 - loss: 0.2050 - val_accuracy: 0.9178 - val_loss: 0.2697
# Epoch 81/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 67s 53ms/step - accuracy: 0.9309 - loss: 0.1984 - val_accuracy: 0.9171 - val_loss: 0.2682
# Epoch 82/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 66s 53ms/step - accuracy: 0.9328 - loss: 0.2014 - val_accuracy: 0.9205 - val_loss: 0.2595

# %%
elapsed_time = datetime.timedelta(seconds=(time.perf_counter() - t))

print('Tiempo de entrenamiento:', elapsed_time)
# Out:
# Tiempo de entrenamiento: 1:34:09.429002

# %% [markdown]
# ## 6. Evaluamos los resultados
#
# Obtengamos una grafica de como el error y la accuracy van evolucionando en cada epoch en los datos de entrenamiento y en la validación

# %%
_, acc = model.evaluate(x_test_scaled, y_test, verbose=0)
print('> %.3f' % (acc * 100.0))
# Out:
# > 91.350

# %%
plt.title('Cross Entropy Loss')
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='orange', label='val')
plt.legend()
plt.show()

plt.title('Classification Accuracy')
plt.plot(history.history['accuracy'], color='blue', label='train')
plt.plot(history.history['val_accuracy'], color='orange', label='val')
plt.legend()
plt.show()

# %% [markdown]
# El coste podemos ver que es estable y es en el epoch 15 que se fija en un valor. Además la accuracy baila alrededor de 0.10. No se puede decir que sea un modelo muy bueno.
#
# Veamos que tipo de predicciones estoy obteniendo sobre el conjunto de test (vamos a pintar las imagenes y sus clasificaciones)

# %%
predictions = model.predict(x_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step

# %% [markdown]
# Una de las ventajas de Python es que hay montones de funciones y código realizado por terceras personas. Aquí me he fusilado unas bonitas funciones (que he adaptado un poco a mis necesidades) para poder pintar las imagenes, su label (ground truth) y las clasificaciones que hemos realizado.

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %% [markdown]
# Dibujamos las primeras imagenes, con las predicciones y sus valores reales (un total de 20 imagenes, para no abusar de vuestros laptops)
#
# Coloreamos las prediciones correctas en azul y los fallos en rojo. Aunque primero he impreso las etiquetas para que tengamos una referencia al grafico.

# %%
i = 0
for l in cifar10_labels:
    print(i, l)
    i += 1

num_rows = 5
num_cols = 4
start = 650
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i+start, predictions[i+start], y_test, x_test)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i+start, predictions[i+start], y_test)
plt.tight_layout()
plt.show()
# Out:
# 0 airplane
# 1 automobile
# 2 bird
# 3 cat
# 4 deer
# 5 dog
# 6 frog
# 7 horse
# 8 ship
# 9 truck

# %% [markdown]
# ## 7. Guardamos el modelo para futuras evaluaciones
#
# Id cambiando los nombres del archivo para ir guardando los diversos proyectos.
# Aquí lo guardamos en "local", pero recordad que lo ideal es que lo guardeis en Google Drive (teneis que montar la unidad, fijar la ruta y allí guardar el modelo .h5)

# %%
ruta_googledrive = "/content/drive/MyDrive/" # A revisar en vuestra instancia

model.save(ruta_googledrive+'cifar10_base_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
